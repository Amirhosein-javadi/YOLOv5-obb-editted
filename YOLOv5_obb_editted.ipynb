# %% [markdown]
# <a href="https://colab.research.google.com/github/Amirhosein-javadi/YOLOv5-obb-editted/blob/main/YOLOv5_obb_editted.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Roboflow and data**

# %%
# %cd /content
# !mkdir /content/datasets/
# Out:
# /content

# %%
# !pip install roboflow
exit()
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 kB 3.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 7.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 8.8 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 6.7 MB/s eta 0:00:00
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9657 sha256=78a13a0451603abc3140ad304d5870109d8b7426632567585d8eddcdf7c17f1b
#   Stored in directory: /root/.cache/pip/wheels/8b/f1/7f/5c94f0a7a505ca1c81cd1d9208ae2064675d97582078e6c769
# Successfully built wget
# ...
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.0.9
#     Uninstalling pyparsing-3.0.9:
#       Successfully uninstalled pyparsing-3.0.9
#   Attempting uninstall: idna
#     Found existing installation: idna 3.4
# ...

# %%
# %cd /content/datasets/

from roboflow import Roboflow
rf = Roboflow(api_key="KdyzhxZx8EoSBwkDqpaO")
project = rf.workspace("taarlab-e2cvo").project("obb_grasp")
dataset = project.version(1).download("yolov5-obb")
# Out:
# /content/datasets
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to OBB_Grasp-1 in yolov5-obb:: 100%|██████████| 860/860 [00:00<00:00, 1283.56it/s]

# %% [markdown]
# **Rename OBB_Grasp-1 to roboflow**

# %% [markdown]
# **Python Dependency**

# %%
# !python --version
# Out:
# Python 3.10.12

# %%
# !sudo update-alternatives --install /usr/bin/python3 python3 /usr/bin/python3.8 1

# %% [markdown]
# **press 2 for installing python3.8 in the following cell after running**

# %%
# !sudo update-alternatives --config python3
# Out:
# There are 2 choices for the alternative python3 (providing /usr/bin/python3).
#
#   Selection    Path                 Priority   Status
# ------------------------------------------------------------
# * 0            /usr/bin/python3.10   2         auto mode
#   1            /usr/bin/python3.10   2         manual mode
#   2            /usr/bin/python3.8    1         manual mode
#
# Press <enter> to keep the current choice[*], or type selection number: 2
# update-alternatives: using /usr/bin/python3.8 to provide /usr/bin/python3 (python3) in manual mode

# %%
# !python3 --version
# Out:
# Python 3.8.10

# %%
# !sudo apt install python3-pip
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# python3-pip is already the newest version (20.0.2-5ubuntu1.8).
# 0 upgraded, 0 newly installed, 0 to remove and 38 not upgraded.

# %%
# !pip3 install torch==1.10.1+cu113 torchvision==0.11.2+cu113 torchaudio==0.10.1+cu113 -f https://download.pytorch.org/whl/cu113/torch_stable.html
# !nvcc -V
# !python
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://download.pytorch.org/whl/cu113/torch_stable.html
# ...
#      |████████████████████████████████| 1821.4 MB 3.6 kB/s
# ...
#      |████████████████████████████████| 24.6 MB 1.5 MB/s
# ...
#      |████████████████████████████████| 2.9 MB 4.7 MB/s
# ...
#      |████████████████████████████████| 3.3 MB 8.6 MB/s
# ...
#      |████████████████████████████████| 17.3 MB 983 kB/s
# ...
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2022 NVIDIA Corporation
# Built on Wed_Sep_21_10:33:58_PDT_2022
# Cuda compilation tools, release 11.8, V11.8.89
# Build cuda_11.8.r11.8/compiler.31833905_0
# Python 3.8.10 (default, May 26 2023, 14:05:08)
# [GCC 9.4.0] on linux
# Type "help", "copyright", "credits" or "license" for more information.
# >>> import torch
# >>> torch.version.cuda
# '11.3'
# >>> exit()

# %% [markdown]
# ```
# >>> import torch
# >>> torch.version.cuda
# >>> exit()
# ```

# %%
# %cd /content/
# Out:
# /content

# %%
# !git clone https://github.com/hukaixuan19970627/yolov5_obb.git
# Out:
# Cloning into 'yolov5_obb'...
# remote: Enumerating objects: 704, done.
# remote: Counting objects: 100% (162/162), done.
# remote: Compressing objects: 100% (42/42), done.
# remote: Total 704 (delta 123), reused 120 (delta 120), pack-reused 542
# Receiving objects: 100% (704/704), 18.16 MiB | 11.26 MiB/s, done.
# Resolving deltas: 100% (323/323), done.

# %%
# %cd /content/yolov5_obb/
# !pip install -r requirements.txt
# Out:
# /content/yolov5_obb
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 9.2 MB 4.4 MB/s
# ...
#      |████████████████████████████████| 61.8 MB 137 kB/s
# ...
#      |████████████████████████████████| 701 kB 66.4 MB/s
# ...
#      |████████████████████████████████| 62 kB 1.2 MB/s
# ...
#      |████████████████████████████████| 34.5 MB 25 kB/s
# ...
#      |████████████████████████████████| 77 kB 4.5 MB/s
# ...
#      |████████████████████████████████| 5.6 MB 48.2 MB/s
# ...
#      |████████████████████████████████| 12.3 MB 48.3 MB/s
# ...
#      |████████████████████████████████| 293 kB 65.5 MB/s
# ...
#      |████████████████████████████████| 4.4 MB 50.1 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 56.2 MB/s
# ...
#      |████████████████████████████████| 247 kB 58.7 MB/s
# ...
#      |████████████████████████████████| 98 kB 8.3 MB/s
# ...
#      |████████████████████████████████| 48 kB 5.3 MB/s
# ...
#      |████████████████████████████████| 300 kB 75.9 MB/s
# ...

# %%
# %cd utils/nms_rotated
# !python setup.py develop #or "pip install -v -e ."
# Out:
# /content/yolov5_obb/utils/nms_rotated
# No CUDA runtime is found, using CUDA_HOME='/usr/local/cuda'
# Compiling nms_rotated_ext without CUDA
# running develop
# running egg_info
# creating nms_rotated.egg-info
# writing nms_rotated.egg-info/PKG-INFO
# writing dependency_links to nms_rotated.egg-info/dependency_links.txt
# writing top-level names to nms_rotated.egg-info/top_level.txt
# writing manifest file 'nms_rotated.egg-info/SOURCES.txt'
# /usr/local/lib/python3.8/dist-packages/torch/utils/cpp_extension.py:381: UserWarning: Attempted to use ninja as the BuildExtension backend but we could not find ninja.. Falling back to using the slow distutils backend.
#   warnings.warn(msg.format('we could not find ninja.'))
# reading manifest file 'nms_rotated.egg-info/SOURCES.txt'
# writing manifest file 'nms_rotated.egg-info/SOURCES.txt'
# running build_ext
# building '.nms_rotated_ext' extension
# creating build
# creating build/temp.linux-x86_64-3.8
# ...

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# %cd /content/yolov5_obb/
# !python train.py --data /content/datasets/roboflow/data.yaml --epochs 1 --batch-size 1 --img 1024 --device cpu --exist-ok
# Out:
# /content/yolov5_obb
# train: weights=weights/yolov5n.pt, cfg=, data=/content/datasets/roboflow/data.yaml, hyp=data/hyps/obb/hyp.finetune_dota.yaml, epochs=1, batch_size=1, imgsz=1024, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=cpu, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=True, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/hukaixuan19970627/yolov5_obb ✅
# YOLOv5 🚀 b00c3f2 torch 1.10.1+cu113 CPU
#
# ...

# %%
# %cd /content/yolov5_obb/
# Out:
# /content/yolov5_obb

# %%
# !python detect.py --weights 'runs/train/exp/weights/best.pt' --source '../datasets/roboflow/valid/images' --conf-thres 0.01 --img 416 --device cpu --agnostic
# Out:
# detect: weights=['runs/train/exp/weights/best.pt'], source=../datasets/roboflow/valid/images, imgsz=[416, 416], conf_thres=0.01, iou_thres=0.2, max_det=1000, device=cpu, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=True, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=2, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 b00c3f2 torch 1.10.1+cu113 CPU
#
# Fusing layers...
# Model Summary: 213 layers, 2008117 parameters, 0 gradients, 4.9 GFLOPs
# image 1/35 /content/datasets/roboflow/valid/images/IMG_0385_jpg.rf.69cc3550a46c6a62c76c346742556804.jpg: 416x416 Done. (0.150s)
# image 2/35 /content/datasets/roboflow/valid/images/IMG_0389_jpg.rf.0e99e53b649ce8de3775eb5b3189a2a4.jpg: 416x416 Done. (0.121s)
# image 3/35 /content/datasets/roboflow/valid/images/IMG_0401_jpg.rf.a7bac9d1f788047616dd88620b328b55.jpg: 416x416 Done. (0.120s)
# ...

# %%
# %cd /content/yolov5_obb/runs/detect/exp/
# Out:
# /content/yolov5_obb/runs/detect/exp

# %%
import os, random
random_file = random.choice(os.listdir("/content/yolov5_obb/runs/detect/exp"))

from IPython.display import Image
Image(random_file)
